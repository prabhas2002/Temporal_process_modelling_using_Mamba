# %% [markdown]
# # Metrics (log likeyhood, Accuracy, RMSE)

# %%
#stack overflow
def extract_last_testing_results(log_file):
    """
    Extract metrics (log-likelihood, accuracy, RMSE) from the last meaningful line of the log file.
    
    Parameters:
        log_file (str): Path to the log file.
    
    Returns:
        tuple: A tuple containing the maximum log-likelihood (ll), 
               maximum accuracy, and minimum RMSE as floats.
    """
    with open(log_file, 'r') as file:
        lines = file.readlines()

    # Get the second-to-last non-empty line (as per your requirement)
    last_row = lines[-2].strip() if lines else None

    if last_row:
        # Extract metrics using known structure
        parts = last_row.split(",")
        ll = float(parts[0].split(":")[-1].strip())
        accuracy = float(parts[1].split(":")[-1].strip())
        rmse = float(parts[2].split(":")[-1].strip())
        return ll, accuracy, rmse
    else:
        return None, None, None  # Default if no valid line found

# File paths for different folds
base_path_so = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_so'
base_path_mamba = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_so'

# Loop through the folds
folds = ['fold1', 'fold2', 'fold3', 'fold4', 'fold5']

print("Results from Logs:")
for fold in folds:
    # Construct log file paths for THP and Mamba
    log_file1 = f"{base_path_so}/{fold}/Logs/gatech/log.txt"
    log_file2 = f"{base_path_mamba}/{fold}/Logs/gatech/log.txt"
    
    # Extract results for THP and Mamba
    loglikelihood1, accuracy1, rmse1 = extract_last_testing_results(log_file1)
    loglikelihood2, accuracy2, rmse2 = extract_last_testing_results(log_file2)
    
    # Print results for the current fold
    print(f"Fold: {fold}")
    print(f"  THP - Log-Likelihood: {loglikelihood1}, Accuracy: {accuracy1}, RMSE: {rmse1}")
    print(f"  Mamba - Log-Likelihood: {loglikelihood2}, Accuracy: {accuracy2}, RMSE: {rmse2}")
# Out:
# Results from Logs:
# Fold: fold1
#   THP - Log-Likelihood: -2.74755, Accuracy: 0.45478, RMSE: 108.0268
#   Mamba - Log-Likelihood: -2.58394, Accuracy: 0.46586, RMSE: 104.3825
# Fold: fold2
#   THP - Log-Likelihood: -2.77963, Accuracy: 0.44553, RMSE: 113.25955
#   Mamba - Log-Likelihood: -2.59038, Accuracy: 0.45546, RMSE: 109.73458
# Fold: fold3
#   THP - Log-Likelihood: -2.7455, Accuracy: 0.43722, RMSE: 111.58695
#   Mamba - Log-Likelihood: -2.58523, Accuracy: 0.44857, RMSE: 106.74456
# Fold: fold4
#   THP - Log-Likelihood: -2.67805, Accuracy: 0.43942, RMSE: 108.68676
#   Mamba - Log-Likelihood: -2.498, Accuracy: 0.45253, RMSE: 103.07407
# Fold: fold5
#   THP - Log-Likelihood: -2.64864, Accuracy: 0.4454, RMSE: 108.79714
#   Mamba - Log-Likelihood: -2.44402, Accuracy: 0.45775, RMSE: 103.9754

# %%
#retweet

def extract_last_testing_results(log_file):
    # Read the .tex file and extract the last row
    with open(log_file, 'r') as file:
        lines = file.readlines()

    # Get the last before non-empty line
    last_row = lines[-2].strip() if lines else None

    # Display the last row
    #print("Last row:", last_row)
    # Extract metrics using known structure
    parts = last_row.split(",")
    ll = float(parts[0].split(":")[-1].strip())
    accuracy = float(parts[1].split(":")[-1].strip())
    rmse = float(parts[2].split(":")[-1].strip())
    return ll, accuracy, rmse
   


# File paths
log_file1_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_retweet/Logs/gatech/log.txt'
log_file2_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_retweet/Logs/gatech/log.txt'

# Extract results
loglikelihood1, accuracy1, rmse1 = extract_last_testing_results(log_file1_so_fold1)
loglikelihood2, accuracy2, rmse2 = extract_last_testing_results(log_file2_so_fold1)

# Print results
print(f"THP - Log-Likelihood: {loglikelihood1}, Accuracy: {accuracy1}, RMSE: {rmse1}")
print(f"Mamba-TP - Log-Likelihood: {loglikelihood2}, Accuracy: {accuracy2}, RMSE: {rmse2}")
# Out:
# THP - Log-Likelihood: -7.51009, Accuracy: 0.54516, RMSE: 35047.81538
# Mamba-TP - Log-Likelihood: -7.54929, Accuracy: 0.54293, RMSE: 34840.04422

# %%
#mimic
def extract_last_testing_results(log_file):
    """
    Extract metrics (log-likelihood, accuracy, RMSE) from the last meaningful line of the log file.
    
    Parameters:
        log_file (str): Path to the log file.
    
    Returns:
        tuple: A tuple containing the maximum log-likelihood (ll), 
               maximum accuracy, and minimum RMSE as floats.
    """
    with open(log_file, 'r') as file:
        lines = file.readlines()

    # Get the second-to-last non-empty line (as per your requirement)
    last_row = lines[-2].strip() if lines else None

    if last_row:
        # Extract metrics using known structure
        parts = last_row.split(",")
        ll = float(parts[0].split(":")[-1].strip())
        accuracy = float(parts[1].split(":")[-1].strip())
        rmse = float(parts[2].split(":")[-1].strip())
        return ll, accuracy, rmse
    else:
        return None, None, None  # Default if no valid line found

# File paths for different folds
base_path_so = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_mimic'
base_path_mamba = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_mimic'

# Loop through the folds
folds = ['fold1', 'fold2', 'fold3', 'fold4', 'fold5']

print("Results from Logs:")
for fold in folds:
    # Construct log file paths for THP and Mamba
    log_file1 = f"{base_path_so}/{fold}/Logs/gatech/log.txt"
    log_file2 = f"{base_path_mamba}/{fold}/Logs/gatech/log.txt"
    
    # Extract results for THP and Mamba
    loglikelihood1, accuracy1, rmse1 = extract_last_testing_results(log_file1)
    loglikelihood2, accuracy2, rmse2 = extract_last_testing_results(log_file2)
    
    # Print results for the current fold
    print(f"Fold: {fold}")
    print(f"  THP - Log-Likelihood: {loglikelihood1}, Accuracy: {accuracy1}, RMSE: {rmse1}")
    print(f"  Mamba - Log-Likelihood: {loglikelihood2}, Accuracy: {accuracy2}, RMSE: {rmse2}")
# Out:
# Results from Logs:
# Fold: fold1
#   THP - Log-Likelihood: -5.43443, Accuracy: 0.90206, RMSE: 1.2412
#   Mamba - Log-Likelihood: -5.44275, Accuracy: 0.89175, RMSE: 1.19889
# Fold: fold2
#   THP - Log-Likelihood: -6.10428, Accuracy: 0.91566, RMSE: 1.45457
#   Mamba - Log-Likelihood: -6.12564, Accuracy: 0.90964, RMSE: 1.37576
# Fold: fold3
#   THP - Log-Likelihood: -6.73446, Accuracy: 0.86667, RMSE: 1.31451
#   Mamba - Log-Likelihood: -6.75518, Accuracy: 0.85333, RMSE: 1.2776
# Fold: fold4
#   THP - Log-Likelihood: -6.77854, Accuracy: 0.83444, RMSE: 1.35875
#   Mamba - Log-Likelihood: -6.87703, Accuracy: 0.84106, RMSE: 1.28612
# Fold: fold5
#   THP - Log-Likelihood: -5.76845, Accuracy: 0.87302, RMSE: 1.39841
#   Mamba - Log-Likelihood: -5.9075, Accuracy: 0.84656, RMSE: 1.38495

# %%
#cont time
def extract_last_testing_results(log_file):
    # Read the .tex file and extract the last row
    with open(log_file, 'r') as file:
        lines = file.readlines()

    # Get the last before non-empty line
    last_row = lines[-2].strip() if lines else None

    # Display the last row
    #print("Last row:", last_row)
    # Extract metrics using known structure
    parts = last_row.split(",")
    ll = float(parts[0].split(":")[-1].strip())
    accuracy = float(parts[1].split(":")[-1].strip())
    rmse = float(parts[2].split(":")[-1].strip())
    return ll, accuracy, rmse
   


# File paths
log_file1_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_conttime/Logs/gatech/log.txt'
log_file2_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_conttime/Logs/gatech/log.txt'

# Extract results
loglikelihood1, accuracy1, rmse1 = extract_last_testing_results(log_file1_so_fold1)
loglikelihood2, accuracy2, rmse2 = extract_last_testing_results(log_file2_so_fold1)

# Print results
print(f"THP - Log-Likelihood: {loglikelihood1}, Accuracy: {accuracy1}, RMSE: {rmse1}")
print(f"Mamba-TP - Log-Likelihood: {loglikelihood2}, Accuracy: {accuracy2}, RMSE: {rmse2}")
# Out:
# THP - Log-Likelihood: -1.276, Accuracy: 0.38554, RMSE: 1.86657
# Mamba-TP - Log-Likelihood: -1.29939, Accuracy: 0.38802, RMSE: 1.86822

# %%
# book order
def extract_last_testing_results(log_file):
    # Read the .tex file and extract the last row
    with open(log_file, 'r') as file:
        lines = file.readlines()

    # Get the last before non-empty line
    last_row = lines[-2].strip() if lines else None

    # Display the last row
    #print("Last row:", last_row)
    # Extract metrics using known structure
    parts = last_row.split(",")
    ll = float(parts[0].split(":")[-1].strip())
    accuracy = float(parts[1].split(":")[-1].strip())
    rmse = float(parts[2].split(":")[-1].strip())
    return ll, accuracy, rmse
   


# File paths
log_file1_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_bookorder/fold1/Logs/gatech/log.txt'
log_file2_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_bookorder/fold1/Logs/gatech/log.txt'

# Extract results
loglikelihood1, accuracy1, rmse1 = extract_last_testing_results(log_file1_so_fold1)
loglikelihood2, accuracy2, rmse2 = extract_last_testing_results(log_file2_so_fold1)

# Print results
print(f"THP - Log-Likelihood: {loglikelihood1}, Accuracy: {accuracy1}, RMSE: {rmse1}")
print(f"Mamba-TP - Log-Likelihood: {loglikelihood2}, Accuracy: {accuracy2}, RMSE: {rmse2}")
# Out:
# THP - Log-Likelihood: -0.99204, Accuracy: 0.58439, RMSE: 1.58822
# Mamba-TP - Log-Likelihood: -0.7876, Accuracy: 0.59997, RMSE: 1.35798

# %%
#missing

def extract_last_testing_results(log_file):
    # Read the .tex file and extract the last row
    with open(log_file, 'r') as file:
        lines = file.readlines()

    # Get the last before non-empty line
    last_row = lines[-2].strip() if lines else None

    # Display the last row
    #print("Last row:", last_row)
    # Extract metrics using known structure
    parts = last_row.split(",")
    ll = float(parts[0].split(":")[-1].strip())
    accuracy = float(parts[1].split(":")[-1].strip())
    rmse = float(parts[2].split(":")[-1].strip())
    return ll, accuracy, rmse
   


# File paths
log_file1_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_missing/Logs/gatech/log.txt'
log_file2_so_fold1 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_missing/Logs/gatech/log.txt'

# Extract results
loglikelihood1, accuracy1, rmse1 = extract_last_testing_results(log_file1_so_fold1)
loglikelihood2, accuracy2, rmse2 = extract_last_testing_results(log_file2_so_fold1)

# Print results
print(f"THP - Log-Likelihood: {loglikelihood1}, Accuracy: {accuracy1}, RMSE: {rmse1}")
print(f"Mamba-TP - Log-Likelihood: {loglikelihood2}, Accuracy: {accuracy2}, RMSE: {rmse2}")
# Out:
# THP - Log-Likelihood: -1.78726, Accuracy: 0.4135, RMSE: 3.04287
# Mamba-TP - Log-Likelihood: -1.82436, Accuracy: 0.4135, RMSE: 3.04204

# %% [markdown]
# # PLOTS

# %%
import matplotlib.pyplot as plt

def parse_log_file(log_file):
    epochs = []
    loglikelihoods = []
    accuracies = []
    rmses = []

    with open(log_file, 'r') as file:
        lines = file.readlines()
        epoch = 0
        for line in lines:
            if ' - (Testing)' in line:
                epoch += 1
                parts = line.split(",")
                loglikelihood = float(parts[0].split(":")[-1].strip())
                accuracy = float(parts[1].split(":")[-1].strip())
                rmse = float(parts[2].split(":")[-1].strip())

                epochs.append(epoch)
                loglikelihoods.append(loglikelihood)
                accuracies.append(accuracy)
                rmses.append(rmse)

    return epochs, loglikelihoods, accuracies, rmses

def calculate_ema(values, alpha=0.3):
    ema_values = []
    ema = values[0]  # Start with the first value
    for value in values:
        ema = alpha * value + (1 - alpha) * ema
        ema_values.append(ema)
    return ema_values

# File paths
log_file1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_so/fold4/Logs/gatech/log.txt'
log_file2 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_so/fold4/Logs/gatech/log.txt'

# Parse log files
epochs1, loglikelihoods1, accuracies1, rmses1 = parse_log_file(log_file1)
epochs2, loglikelihoods2, accuracies2, rmses2 = parse_log_file(log_file2)

# Calculate EMA
ema_loglikelihoods1 = calculate_ema(loglikelihoods1)
ema_loglikelihoods2 = calculate_ema(loglikelihoods2)
ema_accuracies1 = calculate_ema(accuracies1)
ema_accuracies2 = calculate_ema(accuracies2)
ema_rmses1 = calculate_ema(rmses1)
ema_rmses2 = calculate_ema(rmses2)

# Consider only the first 50 epochs
epochs1 = epochs1[:50]
loglikelihoods1 = loglikelihoods1[:50]
accuracies1 = accuracies1[:50]
rmses1 = rmses1[:50]
ema_loglikelihoods1 = ema_loglikelihoods1[:50]
ema_accuracies1 = ema_accuracies1[:50]
ema_rmses1 = ema_rmses1[:50]

epochs2 = epochs2[:50]
loglikelihoods2 = loglikelihoods2[:50]
accuracies2 = accuracies2[:50]
rmses2 = rmses2[:50]
ema_loglikelihoods2 = ema_loglikelihoods2[:50]
ema_accuracies2 = ema_accuracies2[:50]
ema_rmses2 = ema_rmses2[:50]

# Plot Log-Likelihood
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_loglikelihoods1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_loglikelihoods2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Log-Likelihood')
plt.title('Log-Likelihood per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_accuracies1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_accuracies2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot RMSE
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_rmses1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_rmses2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.title('RMSE per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
#mimic
import matplotlib.pyplot as plt

def parse_log_file(log_file):
    epochs = []
    loglikelihoods = []
    accuracies = []
    rmses = []

    with open(log_file, 'r') as file:
        lines = file.readlines()
        epoch = 0
        for line in lines:
            if ' - (Testing)' in line:
                epoch += 1
                parts = line.split(",")
                loglikelihood = float(parts[0].split(":")[-1].strip())
                accuracy = float(parts[1].split(":")[-1].strip())
                rmse = float(parts[2].split(":")[-1].strip())

                epochs.append(epoch)
                loglikelihoods.append(loglikelihood)
                accuracies.append(accuracy)
                rmses.append(rmse)

    return epochs, loglikelihoods, accuracies, rmses

def calculate_ema(values, alpha=0.3):
    ema_values = []
    ema = values[0]  # Start with the first value
    for value in values:
        ema = alpha * value + (1 - alpha) * ema
        ema_values.append(ema)
    return ema_values

# File paths
log_file1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_mimic/fold3/Logs/gatech/log.txt'
log_file2 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_mimic/fold3/Logs/gatech/log.txt'

# Parse log files
epochs1, loglikelihoods1, accuracies1, rmses1 = parse_log_file(log_file1)
epochs2, loglikelihoods2, accuracies2, rmses2 = parse_log_file(log_file2)

# Calculate EMA
ema_loglikelihoods1 = calculate_ema(loglikelihoods1)
ema_loglikelihoods2 = calculate_ema(loglikelihoods2)
ema_accuracies1 = calculate_ema(accuracies1)
ema_accuracies2 = calculate_ema(accuracies2)
ema_rmses1 = calculate_ema(rmses1)
ema_rmses2 = calculate_ema(rmses2)

# Consider only the first 50 epochs
epochs1 = epochs1[:50]
loglikelihoods1 = loglikelihoods1[:50]
accuracies1 = accuracies1[:50]
rmses1 = rmses1[:50]
ema_loglikelihoods1 = ema_loglikelihoods1[:50]
ema_accuracies1 = ema_accuracies1[:50]
ema_rmses1 = ema_rmses1[:50]

epochs2 = epochs2[:50]
loglikelihoods2 = loglikelihoods2[:50]
accuracies2 = accuracies2[:50]
rmses2 = rmses2[:50]
ema_loglikelihoods2 = ema_loglikelihoods2[:50]
ema_accuracies2 = ema_accuracies2[:50]
ema_rmses2 = ema_rmses2[:50]

# Plot Log-Likelihood
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_loglikelihoods1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_loglikelihoods2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Log-Likelihood')
plt.title('Log-Likelihood per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_accuracies1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_accuracies2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot RMSE
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_rmses1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_rmses2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.title('RMSE per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
#book order
import matplotlib.pyplot as plt

def parse_log_file(log_file):
    epochs = []
    loglikelihoods = []
    accuracies = []
    rmses = []

    with open(log_file, 'r') as file:
        lines = file.readlines()
        epoch = 0
        for line in lines:
            if ' - (Testing)' in line:
                epoch += 1
                parts = line.split(",")
                loglikelihood = float(parts[0].split(":")[-1].strip())
                accuracy = float(parts[1].split(":")[-1].strip())
                rmse = float(parts[2].split(":")[-1].strip())

                epochs.append(epoch)
                loglikelihoods.append(loglikelihood)
                accuracies.append(accuracy)
                rmses.append(rmse)

    return epochs, loglikelihoods, accuracies, rmses

def calculate_ema(values, alpha=0.3):
    ema_values = []
    ema = values[0]  # Start with the first value
    for value in values:
        ema = alpha * value + (1 - alpha) * ema
        ema_values.append(ema)
    return ema_values

# File paths
log_file1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_bookorder/fold1/Logs/gatech/log.txt'
log_file2 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_bookorder/fold1/Logs/gatech/log.txt'

# Parse log files
epochs1, loglikelihoods1, accuracies1, rmses1 = parse_log_file(log_file1)
epochs2, loglikelihoods2, accuracies2, rmses2 = parse_log_file(log_file2)

# Calculate EMA
ema_loglikelihoods1 = calculate_ema(loglikelihoods1)
ema_loglikelihoods2 = calculate_ema(loglikelihoods2)
ema_accuracies1 = calculate_ema(accuracies1)
ema_accuracies2 = calculate_ema(accuracies2)
ema_rmses1 = calculate_ema(rmses1)
ema_rmses2 = calculate_ema(rmses2)

# Consider only the first 50 epochs
epochs1 = epochs1[:50]
loglikelihoods1 = loglikelihoods1[:50]
accuracies1 = accuracies1[:50]
rmses1 = rmses1[:50]
ema_loglikelihoods1 = ema_loglikelihoods1[:50]
ema_accuracies1 = ema_accuracies1[:50]
ema_rmses1 = ema_rmses1[:50]

epochs2 = epochs2[:50]
loglikelihoods2 = loglikelihoods2[:50]
accuracies2 = accuracies2[:50]
rmses2 = rmses2[:50]
ema_loglikelihoods2 = ema_loglikelihoods2[:50]
ema_accuracies2 = ema_accuracies2[:50]
ema_rmses2 = ema_rmses2[:50]

# Plot Log-Likelihood
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_loglikelihoods1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_loglikelihoods2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Log-Likelihood')
plt.title('Log-Likelihood per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_accuracies1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_accuracies2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot RMSE
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_rmses1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_rmses2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.title('RMSE per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
#retweet
#conttime

import matplotlib.pyplot as plt

def parse_log_file(log_file):
    epochs = []
    loglikelihoods = []
    accuracies = []
    rmses = []

    with open(log_file, 'r') as file:
        lines = file.readlines()
        epoch = 0
        for line in lines:
            if ' - (Testing)' in line:
                epoch += 1
                parts = line.split(",")
                loglikelihood = float(parts[0].split(":")[-1].strip())
                accuracy = float(parts[1].split(":")[-1].strip())
                rmse = float(parts[2].split(":")[-1].strip())

                epochs.append(epoch)
                loglikelihoods.append(loglikelihood)
                accuracies.append(accuracy)
                rmses.append(rmse)

    return epochs, loglikelihoods, accuracies, rmses

def calculate_ema(values, alpha=0.3):
    ema_values = []
    ema = values[0]  # Start with the first value
    for value in values:
        ema = alpha * value + (1 - alpha) * ema
        ema_values.append(ema)
    return ema_values

# File paths
log_file1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_retweet/Logs/gatech/log.txt'
log_file2 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_retweet/Logs/gatech/log.txt'

# Parse log files
epochs1, loglikelihoods1, accuracies1, rmses1 = parse_log_file(log_file1)
epochs2, loglikelihoods2, accuracies2, rmses2 = parse_log_file(log_file2)

# Calculate EMA
ema_loglikelihoods1 = calculate_ema(loglikelihoods1)
ema_loglikelihoods2 = calculate_ema(loglikelihoods2)
ema_accuracies1 = calculate_ema(accuracies1)
ema_accuracies2 = calculate_ema(accuracies2)
ema_rmses1 = calculate_ema(rmses1)
ema_rmses2 = calculate_ema(rmses2)

# Consider only the first 50 epochs
epochs1 = epochs1[:50]
loglikelihoods1 = loglikelihoods1[:50]
accuracies1 = accuracies1[:50]
rmses1 = rmses1[:50]
ema_loglikelihoods1 = ema_loglikelihoods1[:50]
ema_accuracies1 = ema_accuracies1[:50]
ema_rmses1 = ema_rmses1[:50]

epochs2 = epochs2[:50]
loglikelihoods2 = loglikelihoods2[:50]
accuracies2 = accuracies2[:50]
rmses2 = rmses2[:50]
ema_loglikelihoods2 = ema_loglikelihoods2[:50]
ema_accuracies2 = ema_accuracies2[:50]
ema_rmses2 = ema_rmses2[:50]

# Plot Log-Likelihood
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_loglikelihoods1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_loglikelihoods2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Log-Likelihood')
plt.title('Log-Likelihood per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_accuracies1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_accuracies2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot RMSE
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_rmses1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_rmses2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.title('RMSE per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
#conttime

import matplotlib.pyplot as plt

def parse_log_file(log_file):
    epochs = []
    loglikelihoods = []
    accuracies = []
    rmses = []

    with open(log_file, 'r') as file:
        lines = file.readlines()
        epoch = 0
        for line in lines:
            if ' - (Testing)' in line:
                epoch += 1
                parts = line.split(",")
                loglikelihood = float(parts[0].split(":")[-1].strip())
                accuracy = float(parts[1].split(":")[-1].strip())
                rmse = float(parts[2].split(":")[-1].strip())

                epochs.append(epoch)
                loglikelihoods.append(loglikelihood)
                accuracies.append(accuracy)
                rmses.append(rmse)

    return epochs, loglikelihoods, accuracies, rmses

def calculate_ema(values, alpha=0.3):
    ema_values = []
    ema = values[0]  # Start with the first value
    for value in values:
        ema = alpha * value + (1 - alpha) * ema
        ema_values.append(ema)
    return ema_values

# File paths
log_file1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_conttime/Logs/gatech/log.txt'
log_file2 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_conttime/Logs/gatech/log.txt'

# Parse log files
epochs1, loglikelihoods1, accuracies1, rmses1 = parse_log_file(log_file1)
epochs2, loglikelihoods2, accuracies2, rmses2 = parse_log_file(log_file2)

# Calculate EMA
ema_loglikelihoods1 = calculate_ema(loglikelihoods1)
ema_loglikelihoods2 = calculate_ema(loglikelihoods2)
ema_accuracies1 = calculate_ema(accuracies1)
ema_accuracies2 = calculate_ema(accuracies2)
ema_rmses1 = calculate_ema(rmses1)
ema_rmses2 = calculate_ema(rmses2)

# Consider only the first 50 epochs
epochs1 = epochs1[:50]
loglikelihoods1 = loglikelihoods1[:50]
accuracies1 = accuracies1[:50]
rmses1 = rmses1[:50]
ema_loglikelihoods1 = ema_loglikelihoods1[:50]
ema_accuracies1 = ema_accuracies1[:50]
ema_rmses1 = ema_rmses1[:50]

epochs2 = epochs2[:50]
loglikelihoods2 = loglikelihoods2[:50]
accuracies2 = accuracies2[:50]
rmses2 = rmses2[:50]
ema_loglikelihoods2 = ema_loglikelihoods2[:50]
ema_accuracies2 = ema_accuracies2[:50]
ema_rmses2 = ema_rmses2[:50]

# Plot Log-Likelihood
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_loglikelihoods1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_loglikelihoods2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Log-Likelihood')
plt.title('Log-Likelihood per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_accuracies1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_accuracies2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot RMSE
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_rmses1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_rmses2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.title('RMSE per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# %%
#missing

#conttime

import matplotlib.pyplot as plt

def parse_log_file(log_file):
    epochs = []
    loglikelihoods = []
    accuracies = []
    rmses = []

    with open(log_file, 'r') as file:
        lines = file.readlines()
        epoch = 0
        for line in lines:
            if ' - (Testing)' in line:
                epoch += 1
                parts = line.split(",")
                loglikelihood = float(parts[0].split(":")[-1].strip())
                accuracy = float(parts[1].split(":")[-1].strip())
                rmse = float(parts[2].split(":")[-1].strip())

                epochs.append(epoch)
                loglikelihoods.append(loglikelihood)
                accuracies.append(accuracy)
                rmses.append(rmse)

    return epochs, loglikelihoods, accuracies, rmses

def calculate_ema(values, alpha=0.3):
    ema_values = []
    ema = values[0]  # Start with the first value
    for value in values:
        ema = alpha * value + (1 - alpha) * ema
        ema_values.append(ema)
    return ema_values

# File paths
log_file1 = '/data/home/prabhasreddy/DLNLP/Term_paper/thp/data/data_missing/Logs/gatech/log.txt'
log_file2 = '/data/home/prabhasreddy/DLNLP/Term_paper/mamba/data/data_missing/Logs/gatech/log.txt'

# Parse log files
epochs1, loglikelihoods1, accuracies1, rmses1 = parse_log_file(log_file1)
epochs2, loglikelihoods2, accuracies2, rmses2 = parse_log_file(log_file2)

# Calculate EMA
ema_loglikelihoods1 = calculate_ema(loglikelihoods1)
ema_loglikelihoods2 = calculate_ema(loglikelihoods2)
ema_accuracies1 = calculate_ema(accuracies1)
ema_accuracies2 = calculate_ema(accuracies2)
ema_rmses1 = calculate_ema(rmses1)
ema_rmses2 = calculate_ema(rmses2)

# Consider only the first 50 epochs
epochs1 = epochs1[:50]
loglikelihoods1 = loglikelihoods1[:50]
accuracies1 = accuracies1[:50]
rmses1 = rmses1[:50]
ema_loglikelihoods1 = ema_loglikelihoods1[:50]
ema_accuracies1 = ema_accuracies1[:50]
ema_rmses1 = ema_rmses1[:50]

epochs2 = epochs2[:50]
loglikelihoods2 = loglikelihoods2[:50]
accuracies2 = accuracies2[:50]
rmses2 = rmses2[:50]
ema_loglikelihoods2 = ema_loglikelihoods2[:50]
ema_accuracies2 = ema_accuracies2[:50]
ema_rmses2 = ema_rmses2[:50]

# Plot Log-Likelihood
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_loglikelihoods1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_loglikelihoods2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Log-Likelihood')
plt.title('Log-Likelihood per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_accuracies1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_accuracies2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy per Epoch')
plt.legend()
plt.grid(True)
plt.show()

# Plot RMSE
plt.figure(figsize=(12, 6))
plt.plot(epochs1, ema_rmses1, label='THP EMA', linestyle='-', linewidth=2)
plt.plot(epochs2, ema_rmses2, label='Mamba-TP EMA', linestyle='-', linewidth=2)
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.title('RMSE per Epoch')
plt.legend()
plt.grid(True)
plt.show()
